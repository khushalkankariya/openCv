# %% [markdown]
# histogram: allows you to distribution of pixel intensity

# %%
import cv2 as cv
img=cv.imread('D:/openCV/photos/bhed.jpg')
import matplotlib.pyplot as plt

# %%
cv.imshow("original",img)
gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)
cv.imshow("gray",gray)
cv.waitKey(0)
# Out:
# -1

# %%
#grayScale Histogram
# calcHist(images, channels, mask, histSize, ranges[, hist[, accumulate]]) -> hist
img=cv.imread('D:/openCV/photos/darling.jpg')

gray=cv.cvtColor(img,cv.COLOR_BGR2GRAY)


gray_hist=cv.calcHist(gray,[0],None, [256], [0,256])
plt.figure()
plt.title("Grayscale histogram")
plt.xlabel("No. Of Bins")
plt.ylabel("No. Of Pixels")
plt.plot(gray_hist)
plt.xlim([0,256])
plt.show()
cv.imshow("original",img)
cv.imshow("gray",gray)
cv.waitKey(0)
# Out:
# -1

# %%
lst=[1,4,4,684,486,45]
for j,k in enumerate(lst):
    print(j,k)
# Out:
# 0 1
# 1 4
# 2 4
# 3 684
# 4 486
# 5 45

# %%
# can do same with masking

# %%
#RGB Image histogram
plt.figure()
plt.title("color histogram")
plt.xlabel("No. Of Bins")
plt.ylabel("No. Of Pixels")
img=cv.imread('D:/openCV/photos/darling.jpg')
colors=('b','g','r')
for i,col in enumerate(colors):
    hist=cv.calcHist([img],[i], None,[256], [0,266])
    plt.plot(hist,color=col)
    plt.xlim([0,256])
plt.show()
cv.imshow("original",img)
cv.waitKey(0)
# Out:
# -1

# %%
#can do same thing witih  masking
